# %% [markdown]
# # 02 - Preprocessing
#
# Nettoyage, filtrage, equilibrage et export du dataset MLP.

# %%
# !python -m src.data.preprocess

# %%
import json
from pathlib import Path

report = json.loads(Path('data/interim/preprocessing_report.json').read_text(encoding='utf-8'))
report
