# %% [markdown]
# # 01 - Data Understanding
#
# Profil du dataset `antoinejeannot/jurisprudence` pour la classification de juridiction.

# %%
# !python -m src.data.load_dataset --max-per-class 5000

# %%
import json
from pathlib import Path

profile = json.loads(Path('data/interim/raw_profile.json').read_text(encoding='utf-8'))
profile
